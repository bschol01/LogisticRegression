# %%
# Import modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from sklearn.model_selection import train_test_split

# %%
# Read in the .csv file that contains the data
med_rec = pd.read_csv("C:/Users/clown/OneDrive/Documents/MS Data Analytics/Predictive Modeling/Data/medical_clean.csv")

# %%
# Check for missing values
med_rec.isnull().sum().sum()
# Out:
# 0

# %%
# Drop columns that contain individual indentification that isn't necessary to the model
# and rename vague column names to be more descriptive.
med_rec = med_rec.drop(['CaseOrder','Customer_id','Interaction','UID', 'City','County','Zip','State', 'TimeZone','Lat','Lng','Job'], axis=1)
med_rec = med_rec.rename({'Item1':'Timely_admission','Item2':'Timely_treatment','Item3':'Timely_visits','Item4':'Reliability',
               'Item5':'Options','Item6':'Hours_treatment','Item7':'Courteous','Item8':'Active_listening'}, axis='columns')

# %%
# Convert No/Yes to 0/1 in binary variables
boo = ['ReAdmis','Soft_drink','HighBlood','Stroke','Overweight','Arthritis','Diabetes','Hyperlipidemia',
       'BackPain','Anxiety','Allergic_rhinitis','Reflux_esophagitis','Asthma']
med_rec[boo] = med_rec[boo].replace({'No':False, 'Yes':True})

# %%
# Convert data types to category as appropriate to make analysis easier
cat = ['Area','Marital','Gender','Initial_admin','Complication_risk','Services']
med_rec[cat] = med_rec[cat].astype('category')

# %%
# Summary statistics for catigorical variables
med_rec.describe(include=['category'])
# Out:
#          Area  Marital  Gender        Initial_admin Complication_risk  \
# count   10000    10000   10000                10000             10000
# unique      3        5       3                    3                 3
# top     Rural  Widowed  Female  Emergency Admission            Medium
# freq     3369     2045    5018                 5060              4517
#
#           Services
# count        10000
# unique           4
# top     Blood Work
# freq          5265

# %%
# Summary statistics for discrete and
# ordinal variables of the data type int64
med_rec.describe(include=['int64'])
# Out:
#           Population      Children           Age    Doc_visits  \
# count   10000.000000  10000.000000  10000.000000  10000.000000
# mean     9965.253800      2.097200     53.511700      5.012200
# std     14824.758614      2.163659     20.638538      1.045734
# min         0.000000      0.000000     18.000000      1.000000
# 25%       694.750000      0.000000     36.000000      4.000000
# 50%      2769.000000      1.000000     53.000000      5.000000
# 75%     13945.000000      3.000000     71.000000      6.000000
# max    122814.000000     10.000000     89.000000      9.000000
#
#        Full_meals_eaten     vitD_supp  Timely_admission  Timely_treatment  \
# count      10000.000000  10000.000000      10000.000000      10000.000000
# mean           1.001400      0.398900          3.518800          3.506700
# std            1.008117      0.628505          1.031966          1.034825
# min            0.000000      0.000000          1.000000          1.000000
# 25%            0.000000      0.000000          3.000000          3.000000
# 50%            1.000000      0.000000          4.000000          3.000000
# 75%            2.000000      1.000000          4.000000          4.000000
# max            7.000000      5.000000          8.000000          7.000000
#
#        Timely_visits   Reliability       Options  Hours_treatment  \
# count   10000.000000  10000.000000  10000.000000     10000.000000
# mean        3.511100      3.515100      3.496900         3.522500
# std         1.032755      1.036282      1.030192         1.032376
# min         1.000000      1.000000      1.000000         1.000000
# 25%         3.000000      3.000000      3.000000         3.000000
# 50%         4.000000      4.000000      3.000000         4.000000
# 75%         4.000000      4.000000      4.000000         4.000000
# max         8.000000      7.000000      7.000000         7.000000
#
#           Courteous  Active_listening
# count  10000.000000      10000.000000
# mean       3.494000          3.509700
# std        1.021405          1.042312
# min        1.000000          1.000000
# 25%        3.000000          3.000000
# 50%        3.000000          3.000000
# 75%        4.000000          4.000000
# max        7.000000          7.000000

# %%
# Summary statistics for the continous variables 
med_rec.describe(include=['float64'])
# Out:
#               Income   VitD_levels  Initial_days   TotalCharge  \
# count   10000.000000  10000.000000  10000.000000  10000.000000
# mean    40490.495160     17.964262     34.455299   5312.172769
# std     28521.153293      2.017231     26.309341   2180.393838
# min       154.080000      9.806483      1.001981   1938.312067
# 25%     19598.775000     16.626439      7.896215   3179.374015
# 50%     33768.420000     17.951122     35.836244   5213.952000
# 75%     54296.402500     19.347963     61.161020   7459.699750
# max    207249.100000     26.394449     71.981490   9180.728000
#
#        Additional_charges
# count        10000.000000
# mean         12934.528587
# std           6542.601544
# min           3125.703000
# 25%           7986.487755
# 50%          11573.977735
# 75%          15626.490000
# max          30566.070000

# %%
# Summary statistics for binary variables 
# to include the response variable
med_rec.describe(include=['bool'])
# Out:
#        ReAdmis Soft_drink HighBlood Stroke Overweight Arthritis Diabetes  \
# count    10000      10000     10000  10000      10000     10000    10000
# unique       2          2         2      2          2         2        2
# top      False      False     False  False       True     False    False
# freq      6331       7425      5910   8007       7094      6426     7262
#
#        Hyperlipidemia BackPain Anxiety Allergic_rhinitis Reflux_esophagitis  \
# count           10000    10000   10000             10000              10000
# unique              2        2       2                 2                  2
# top             False    False   False             False              False
# freq             6628     5886    6785              6059               5865
#
#        Asthma
# count   10000
# unique      2
# top     False
# freq     7107

# %%
# Establishes a Figure with which subplots can be assigned
fig = plt.figure(figsize=(10,10))
fig_dims = (3,4)

# Creates univariate bar chart subplots for the binary independant predictors
# Seperated by row in figure
plt.subplot2grid(fig_dims,(0, 0))
med_rec['Soft_drink'].value_counts().plot(kind='bar', title='Soft Drink Consumption')
plt.subplot2grid(fig_dims,(0,1))
med_rec['HighBlood'].value_counts().plot(kind='bar',title='High Blood Pressure')
plt.subplot2grid(fig_dims,(0,2))
med_rec['Stroke'].value_counts().plot(kind='bar',title='Stroke')
plt.subplot2grid(fig_dims,(0,3))
med_rec['Overweight'].value_counts().plot(kind='bar',title='Overweight')

plt.subplot2grid(fig_dims,(1,0))
med_rec['Arthritis'].value_counts().plot(kind='bar',title='Arthritis')
plt.subplot2grid(fig_dims,(1,1))
med_rec['Diabetes'].value_counts().plot(kind='bar',title='Diabetes')
plt.subplot2grid(fig_dims,(1,2))
med_rec['Hyperlipidemia'].value_counts().plot(kind='bar',title='Hyperlipidemia')
plt.subplot2grid(fig_dims,(1,3))
med_rec['BackPain'].value_counts().plot(kind='bar',title='BackPain')

plt.subplot2grid(fig_dims,(2,0))
med_rec['Anxiety'].value_counts().plot(kind='bar',title='Anxiety')
plt.subplot2grid(fig_dims,(2,1))
med_rec['Allergic_rhinitis'].value_counts().plot(kind='bar',title='Allergic Rhinitis')
plt.subplot2grid(fig_dims,(2,2))
med_rec['Reflux_esophagitis'].value_counts().plot(kind='bar',title='Reflux Esophagitis')
plt.subplot2grid(fig_dims,(2,3))
med_rec['Asthma'].value_counts().plot(kind='bar',title='Asthma')

# Spaces out the plots and displays the figure
plt.tight_layout()
plt.show()

# %%
# Shows a bar chart for the Response variable
med_rec['ReAdmis'].value_counts().plot(kind='bar',title='Readmitted within a month of release')
plt.show()

# %%
# Establishes a Figure with which subplots can be assigned
fig = plt.figure(figsize=(15,20))
fig_dims = (3,2)

# Creates univariate bar chart subplots for the categorical independant predictors
# Seperated by row in figure
plt.subplot2grid(fig_dims,(0, 0))
med_rec['Area'].value_counts().plot(kind='bar', title='Area')
plt.subplot2grid(fig_dims,(0, 1))
med_rec['Marital'].value_counts().plot(kind='bar', title='Marital Status')

plt.subplot2grid(fig_dims,(1, 0))
med_rec['Gender'].value_counts().plot(kind='bar', title='Gender')
plt.subplot2grid(fig_dims,(1, 1))
med_rec['Initial_admin'].value_counts().plot(kind='bar', title='Initial Admission')

plt.subplot2grid(fig_dims,(2, 0))
med_rec['Complication_risk'].value_counts().plot(kind='bar', title='Complication Risk')
plt.subplot2grid(fig_dims,(2, 1))
med_rec['Services'].value_counts().plot(kind='bar', title='Services')

# Spaces out the plots and displays the figure
plt.tight_layout()
plt.show()

# %%
# Establishes a Figure with which subplots can be assigned
fig = plt.figure(figsize=(15,15))
fig_dims = (4,4)

# Creates univariate box plots of all the discrete predictor variables
# Seperated by row in figure
plt.subplot2grid(fig_dims,(0, 0))
med_rec['Population'].plot(kind='box',title='Population')
plt.subplot2grid(fig_dims,(0, 1))
med_rec['Children'].plot(kind='box', title='Children')
plt.subplot2grid(fig_dims,(0, 2))
med_rec['Age'].plot(kind='box', title='Age')
plt.subplot2grid(fig_dims,(0, 3))
med_rec['Doc_visits'].plot(kind='box', title='Doctor Visits')

plt.subplot2grid(fig_dims,(1, 0))
med_rec['Full_meals_eaten'].plot(kind='box',title='Full Meals Eaten')
plt.subplot2grid(fig_dims,(1, 1))
med_rec['vitD_supp'].plot(kind='box', title='Number Vitamin D Supplements Administered')
plt.subplot2grid(fig_dims,(1, 2))
med_rec['Timely_admission'].plot(kind='box', title='Timely Admission')
plt.subplot2grid(fig_dims,(1, 3))
med_rec['Timely_treatment'].plot(kind='box', title='Timely Treatment')

plt.subplot2grid(fig_dims,(2, 0))
med_rec['Timely_visits'].plot(kind='box',title='Timely Visits')
plt.subplot2grid(fig_dims,(2, 1))
med_rec['Reliability'].plot(kind='box', title='Reliability')
plt.subplot2grid(fig_dims,(2, 2))
med_rec['Options'].plot(kind='box', title='Options')
plt.subplot2grid(fig_dims,(2, 3))
med_rec['Hours_treatment'].plot(kind='box', title='Hours of Treatment')

plt.subplot2grid(fig_dims,(3, 0))
med_rec['Courteous'].plot(kind='box',title='Courteous Staff')
plt.subplot2grid(fig_dims,(3, 1))
med_rec['Active_listening'].plot(kind='box', title='Active Listening')

# Spaces out the plots and displays the figure
plt.tight_layout()
plt.show()

# %%
# Establishes a Figure with which subplots can be assigned
fig = plt.figure(figsize=(15,10))
fig_dims = (2,3)

# Creates univariate histrograms based on the continuous predictor variables
# Seperated by row in figure
plt.subplot2grid(fig_dims,(0, 0))
med_rec['Income'].plot(kind='hist',title='Income')
plt.subplot2grid(fig_dims,(0, 1))
med_rec['VitD_levels'].plot(kind='hist', title='Vitamin D Levels')
plt.subplot2grid(fig_dims,(0, 2))
med_rec['Initial_days'].plot(kind='hist', title='Initial Days')

plt.subplot2grid(fig_dims,(1, 0))
med_rec['TotalCharge'].plot(kind='hist', title='Total Charge')
plt.subplot2grid(fig_dims,(1, 1))
med_rec['Additional_charges'].plot(kind='hist', title='Additional Charges')

# Spaces out the plots and displays the figure
plt.tight_layout()
plt.show()

# %%
# Establishes a Figure with which subplots can be assigned
fig = plt.figure(figsize=(15,10))
fig_dims = (2,3)

# Creates bivariate boxplots using the ReAdmis response as the X-axis
# and the continuous predictor variables as the Y-axis
plt.subplot2grid(fig_dims,(0, 0))
sns.boxenplot(x=med_rec.ReAdmis, y=med_rec.Income)
#sns.stripplot(x=med_rec.ReAdmis, y=med_rec.Income)
plt.subplot2grid(fig_dims,(0, 1))
sns.boxenplot(x=med_rec.ReAdmis, y=med_rec.VitD_levels)
#sns.stripplot(x=med_rec.ReAdmis, y=med_rec.VitD_levels)
plt.subplot2grid(fig_dims,(0, 2))
sns.boxenplot(x=med_rec.ReAdmis, y=med_rec.Initial_days)
#sns.stripplot(x=med_rec.ReAdmis, y=med_rec.Initial_days)
plt.subplot2grid(fig_dims,(1, 0))
sns.boxenplot(x=med_rec.ReAdmis, y=med_rec.TotalCharge)
#sns.stripplot(x=med_rec.ReAdmis, y=med_rec.TotalCharge)
plt.subplot2grid(fig_dims,(1, 1))
sns.boxenplot(x=med_rec.ReAdmis, y=med_rec.Additional_charges)
#sns.stripplot(x=med_rec.ReAdmis, y=med_rec.Additional_charges)

# Spaces out the plots and displays the figure
plt.tight_layout()
plt.show()

# %%
#Change plots from inline to account for large figure size
# %matplotlib ipympl

# Establishes a Figure with which subplots can be assigned
fig = plt.figure(figsize=(80,40))
col_max=10
row_max=5
fig_dims = (col_max,row_max)

i = 0
j = 0
for col, row in med_rec.iteritems():
    plt.subplot2grid(fig_dims,(i, j))
    sns.histplot(x=med_rec[col], hue=med_rec.ReAdmis, multiple='dodge')
    j+=1
    if (j == row_max):
        j=0
        i+=1
    if (i == col_max):
        break
# Spaces out the plots and displays the figure
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
# Change plots back to inline
# %matplotlib inline

# %%
# Create Dummy Variables for all categorical independent variables
med_rec=pd.get_dummies(med_rec, drop_first=True)

# %%
# Split the data into dependent and independent variables
dependent = med_rec.ReAdmis
independent = med_rec.drop(columns=['ReAdmis'])

# %%
# Split into train and test data
x_train_data, x_test_data, y_train_data, y_test_data = train_test_split(independent, dependent, test_size = 0.3)

# %%
# Build the Model
model = sm.Logit(y_train_data,x_train_data.astype(float)).fit()
print(model.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.031528
#          Iterations 14
#                                     Results: Logit
# =======================================================================================
# Model:                      Logit                    Pseudo R-squared:         0.952
# Dependent Variable:         ReAdmis                  AIC:                      533.3879
# Date:                       2021-10-02 13:15         BIC:                      848.6565
# No. Observations:           7000                     Log-Likelihood:           -220.69
# Df Model:                   45                       LL-Null:                  -4610.0
# Df Residuals:               6954                     LLR p-value:              0.0000
# Converged:                  1.0000                   Scale:                    1.0000
# No. Iterations:             14.0000
# ---------------------------------------------------------------------------------------
#                                      Coef.   Std.Err.    z     P>|z|   [0.025   0.975]
# ---------------------------------------------------------------------------------------
# Population                            0.0000   0.0000   0.7155 0.4743  -0.0000   0.0000
# Children                              0.0934   0.0585   1.5968 0.1103  -0.0212   0.2080
# Age                                   0.0058   0.0189   0.3065 0.7592  -0.0312   0.0427
# Income                                0.0000   0.0000   1.4029 0.1606  -0.0000   0.0000
# VitD_levels                           0.0232   0.0609   0.3806 0.7035  -0.0962   0.1426
# Doc_visits                            0.0488   0.1297   0.3764 0.7066  -0.2054   0.3031
# Full_meals_eaten                     -0.0106   0.1343  -0.0793 0.9368  -0.2738   0.2525
# vitD_supp                            -0.0513   0.2112  -0.2430 0.8080  -0.4654   0.3627
# Soft_drink                            0.1590   0.3063   0.5191 0.6037  -0.4413   0.7592
# HighBlood                             5.0407   0.8406   5.9968 0.0000   3.3932   6.6882
# Stroke                                2.0882   0.3475   6.0097 0.0000   1.4072   2.7692
# Overweight                           -0.5302   0.2876  -1.8437 0.0652  -1.0939   0.0334
# Arthritis                             1.4099   0.2855   4.9387 0.0000   0.8504   1.9694
# Diabetes                              3.1477   0.3659   8.6030 0.0000   2.4306   3.8648
# Hyperlipidemia                        4.3461   0.4185  10.3854 0.0000   3.5259   5.1663
# BackPain                              3.6927   0.3743   9.8651 0.0000   2.9591   4.4264
# Anxiety                               2.0790   0.3239   6.4193 0.0000   1.4442   2.7137
# Allergic_rhinitis                     2.0079   0.2984   6.7293 0.0000   1.4231   2.5928
# Reflux_esophagitis                    1.9401   0.3025   6.4146 0.0000   1.3473   2.5329
# Asthma                               -1.7110   0.3081  -5.5527 0.0000  -2.3150  -1.1071
# Initial_days                          4.8191   0.3421  14.0850 0.0000   4.1485   5.4896
# TotalCharge                          -0.0390   0.0028 -13.8656 0.0000  -0.0446  -0.0335
# Additional_charges                    0.0000   0.0001   0.1291 0.8972  -0.0001   0.0002
# Timely_admission                     -0.2057   0.1979  -1.0392 0.2987  -0.5936   0.1822
# Timely_treatment                      0.1919   0.1701   1.1284 0.2592  -0.1415   0.5253
# Timely_visits                        -0.0133   0.1576  -0.0845 0.9327  -0.3223   0.2956
# Reliability                          -0.0834   0.1432  -0.5825 0.5602  -0.3641   0.1972
# Options                              -0.2734   0.1511  -1.8096 0.0704  -0.5695   0.0227
# Hours_treatment                      -0.0694   0.1555  -0.4466 0.6552  -0.3741   0.2353
# Courteous                             0.2767   0.1493   1.8533 0.0638  -0.0159   0.5693
# Active_listening                     -0.1672   0.1341  -1.2464 0.2126  -0.4300   0.0957
# Area_Suburban                         0.0660   0.3155   0.2092 0.8343  -0.5523   0.6843
# Area_Urban                            0.1206   0.3292   0.3663 0.7141  -0.5246   0.7658
# Marital_Married                      -0.0710   0.4025  -0.1763 0.8601  -0.8598   0.7179
# Marital_Never Married                -0.0776   0.4231  -0.1833 0.8545  -0.9069   0.7517
# Marital_Separated                    -0.5034   0.4272  -1.1784 0.2386  -1.3406   0.3338
# Marital_Widowed                      -0.1557   0.4190  -0.3716 0.7102  -0.9768   0.6655
# Gender_Male                           0.1619   0.2602   0.6224 0.5337  -0.3480   0.6718
# Gender_Nonbinary                     -0.0185   0.8743  -0.0211 0.9831  -1.7320   1.6950
# Initial_admin_Emergency Admission    22.4819   1.6506  13.6202 0.0000  19.2467  25.7170
# Initial_admin_Observation Admission   0.6562   0.3559   1.8435 0.0653  -0.0415   1.3538
# Complication_risk_Low               -18.1404   1.3443 -13.4939 0.0000 -20.7753 -15.5056
# Complication_risk_Medium            -16.3867   1.1923 -13.7438 0.0000 -18.7235 -14.0498
# Services_CT Scan                      1.5475   0.4424   3.4977 0.0005   0.6803   2.4146
# Services_Intravenous                 -0.2918   0.2905  -1.0044 0.3152  -0.8612   0.2776
# Services_MRI                          2.0871   0.6764   3.0857 0.0020   0.7614   3.4128
# =======================================================================================
